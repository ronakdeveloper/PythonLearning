# %%
a = 15 
b = 4

print(a+b)
print(a*b)
print(a/b)
# Out:
# 19
# 60
# 3.75

# %%
birth_year = int(input("Enter your birth year : "))

print(2026-birth_year)
# Out:
# 25

# %%
product_price = 100
gst = 18

product_price += product_price * gst/100

print(product_price)
# Out:
# 118.0

# %%
employee = {"name":"Ronak","department":"Software"}

print(employee["department"])
# Out:
# Software

# %%
monthly_salary = 27300
bonus = 15
annual_salary = monthly_salary*12

print(annual_salary+annual_salary*bonus/100)
# Out:
# 376740.0

# %%
employee_name = input("Enter your name : ")
monthly_salary = float(input("Enter your monthly salary : "))

annual_salary = monthly_salary * 12
tax_amount = annual_salary * 0.2
final_salary = annual_salary - tax_amount

print(f"Employee {employee_name} has annual salary {annual_salary}")
print(f"Tax Deducted is {tax_amount}")
print(f"Final salary is {final_salary}")
