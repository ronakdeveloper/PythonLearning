# %%
name = "Ronak"

print(name)
print(type(name))
# Out:
# Ronak
# <class 'str'>

# %%
## Indexing
name = "Python"

print(name[0])
print(name[1])
print(name[5])
# Out:
# P
# y
# n

# %%
## Negative Indexing
name = "Python"

print(name[-1])
print(name[-2])
print(name[-5])
# Out:
# n
# o
# y

# %%
## Slicing

name = "Hello, My name is Ronak"

print(len(name))
print(name[0:5])
print(name[:5])
print(name[18:23])
print(name[18:])
print(name[::-1])
# Out:
# 23
# Hello
# Hello
# Ronak
# Ronak
# kanoR si eman yM ,olleH

# %%
name = "Hello, My name is Ronak"
name1 = "  Python   "

print(name.upper())
print(name.lower())
print(name1)
print(name1.strip())
print(name.replace('Ronak','Mak'))
print(name.count("a"))
print(name.find("R"))
# Out:
# HELLO, MY NAME IS RONAK
# hello, my name is ronak
#   Python
# Python
# Hello, My name is Mak
# 2
# 18

# %%
data = "Python,SQL,Database,Javascript"

skills = data.split(",")
result = " | ".join(skills)

print(skills)
print(result)
# Out:
# ['Python', 'SQL', 'Database', 'Javascript']
# Python | SQL | Database | Javascript

# %%
name = "Ronak"
role = "Data Engineer"

print(f"My name is {name} and I want to become {role}")
# Out:
# My name is Ronak and I want to become Data Engineer

# %%
name = "  Ronak Makwana  "
name = name.upper()
print(name.strip())

email = "ronakmakwana@gmail.com"
domain = email.split("@")

print(domain[1])

words = "I love data engineering"
count = words.split()
print(len(count))

role = "Data Engineer"
print(role.replace(" ","_"))
# Out:
# RONAK MAKWANA
# gmail.com
# 4
# Data_Engineer

# %%
error = " ERROR: File not found "
error = error.strip().lower().replace(": ",":")
print(error)
# Out:
# error:file not found

# %%
text = "Python"
rev = list(text)
rev.reverse()
''.join(rev)
# Out:
# 'nohtyP'
